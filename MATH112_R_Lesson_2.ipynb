# %% [markdown]
# # DawR Notebook #2: Is It Just a Calculator?
#
# _Lesson Objectives_
#
# 1.   To use help to learn about functions
# 2.   To use R like a better calculator
#
# This notebook traces part of the textbook reading (Ch2) but it is adapted for Google Colab, and you are expected to follow along with both, side-by-side.  You have editing privileges to this document.  Submit your completed notebook to the Google Classroom under 'Notebook #2'.

# %% [markdown]
# # I) **Important Statistics Functions**

# %% [markdown]
# Check out the help page on each of the functions below. **<font color= #C7B8EA;>Report back what they do in the comments below each function.</font>**

# %%
help(mean)
#

# %%
help(median)
#

# %%
help(sd)
#

# %%
help(var)
#

# %%
help(summary)
#

# %%
help(cor)
#

# %% [markdown]
# # II) **Important Math Functions for Data Analysis**

# %% [markdown]
# Check out the help page on each of the functions below. **<font color= #C7B8EA;>Report back what they do in the comments below each function.</font>**

# %%
help(sqrt)
#

# %%
help(log)
#

# %%
help(log10)
#

# %%
help(sum)
#

# %%
help(exp)
#

# %% [markdown]
# # III) **More Numbers at the Same Time!**

# %% [markdown]
# A **vector** is a "list" of data.  We can operator on many data at once using vectors.

# %%
# create vectors x and y
x = c(1,2,3,4)
y = c(-1,2,3,0)

# create your own and call it Fred!
Fred =

# %% [markdown]
# The operations on vectors are often element-wise operations.  To understand what that means, run the code chunks below.
#
# Then, do the math separately on paper to prove to yourself you understand what's happening.

# %%
# what's the output?
x + Fred/y

# %%
# what's the output?
x - y

# %%
# what's the output?
y/Fred

# %%
# what's the output?
x*y*Fred

# %%
# what's the output?
Fred - x^2

# %% [markdown]
# The order of operations still matter in R.  So, err on the side of caution and use parentheses always!  Observe how the code chunks below are significantly different than the corresponding two above.

# %%
(x + Fred)/y

# %%
(Fred - x)^2

# %% [markdown]
# We have addition, substraction, division, and exponents.  **<font color= #C7B8EA;>What is another basic operation from Algebra 1 we haven't tried yet?</font>**  Answer here:

# %% [markdown]
# # III) **Simulation of Data**

# %% [markdown]
# In this section, we will combine elements from Notebooks #1 and #2.  We will
#
# * make data -- like we did in Notebook #1
# * determine the five number summary of the data -- something you learned to do above
# * scale the data -- using a function you learned about above
# * and randomly sample points from the scaled data

# %%
# create a random vector of elements Normally distributed with mean 1e6 and sd 1
data = rnorm(10, mean = 1e6, sd = 1)
# For you: determine the five number summary of the data, fill in the blank
sum_o_data = _____(data)
# For you: we want to scale the data using the natural log, fill in the blank and give this new vector a name
_____ = ____(data)

# we can randomly sample 5 elements from the scaled data using the sample function
sample(NAME_OF_NEW_DATA, size = 5, replace = FALSE)

# %% [markdown]
# **<font color= #C7B8EA;>Describe the output for the code chunk above.</font>** Here:

# %% [markdown]
# # IV) **<font color= #C7B8EA;>Summarize lessons learned in this notebook!</font>**
