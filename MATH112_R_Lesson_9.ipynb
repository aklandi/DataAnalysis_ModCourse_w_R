# %% [markdown]
# # DawR Notebook #9: MOAR CLEANING
#
# _Lesson Objectives_
#
# 1.   To clean and transform data using dplyr methods
#
# This notebook traces the remainder of the textbook reading (Ch13) but it is adapted for Google Colab, and you are expected to follow along with both, side-by-side.  You have editing privileges to this document.  Submit your completed notebook to the Google Classroom under 'Notebook #9'.

# %% [markdown]
# # **More with _dplyr_**
#
# In the last notebook, we learned
#
# *   _arrange_: to order our data
# *   _group\_by_ and _count_: to create a table of counts
# *   _filter_: to filter out rows based on specific conditions
# *   _select_: to select specific columns
# *   _summarize_: to apply a function to a particular variable
#
# You'll be asked to determine certain information from a new data set.

# %%
#install.packages('learningr')
install.packages('cowplot')
#library('learningr')
#data(crab_tag, package = 'learningr')
#?learningr::crab_tag

# %% [markdown]
# 1.    <font color=#C7B8EA>Describe what you learn from the Help page here</font>.

# %%
#head(crab_tag$daylog)
library(dplyr)
DF = crab_tag$daylog
#head(DF)

# %% [markdown]
# 2.   <font color=#C7B8EA>Describe what you learn from the head function</font>.

# %% [markdown]
# 3.    Perhaps we only care about the data in the month of August for year 2008.  <font color=#C7B8EA>Filter the data so that the new data only has August dates</font>.  You will need what you learned from the last two lessons.

# %% [markdown]
# 4.   <font color=#C7B8EA>Calculate the spread of temperature for each crab and add it as a column to the data frame</font>.

# %% [markdown]
# 5.    <font color=#C7B8EA>Calculate the spread of the depth for each crab and add it as a column to the data frame</font>.

# %% [markdown]
# 6.    <font color=#C7B8EA>Create a subset of the data with the identifying information: Date, Batt.Volts, spread_temp, spread_depth</font>.

# %% [markdown]
# 7.    <font color=#C7B8EA>Calculate the six number summary of each of the quantitative variables.  What is the minimum, Q1, median, mean, Q3, and max?  In which direction is each variable skewed?</font>  (If you want to learn more about the five number summary, I have a [statistics video](https://www.youtube.com/watch?v=GN1D2McrpDc&list=PLi7dgbcDJwMLs0CS9H9QBMwHQbRQk3c4H&index=11) for you!)

# %% [markdown]
# 7.   <font color=#C7B8EA>Create a scatterplot of the two time series (on the side by side graph) for the spread of temperature and for the spread of depth</font>.

# %%
library(ggplot2)
library(cowplot)
gg_temp = ggplot(data = NAME_OF_YOUR_DATA, aes(x = Date, y = spread_temp)) + 
      geom_point(color = "blue") + geom_smooth(method=lm) + xlab("August Dates") + 
      ylab("Temperature Spread (Celsius)") + ggtitle("Temperature of Crabby Travels") 
gg_depth = ggplot(data = NAME_OF_YOUR_DATA, aes(x = Date, y = spread_depth)) + 
      geom_point(color = "green") + geom_smooth(method=lm) + xlab("August Dates") + 
      ylab("Depth Spread (meters)") + ggtitle("Depth of Crabby Travels") 

# extra credit to anyone who can figure out how to get this graph to display bigger and scaled correctly :-\
plot_grid(gg_temp, gg_depth, labels = "AUTO")

# %% [markdown]
# 8.   <font color=#C7B8EA>What does the graph indicate about this particular crab's journey during the month of August?</font>

# %% [markdown]
# > You now have the skills to tackle dirtier data.  Woot.  Young padawon, I now leave you to the task of making the data-verse a cleaner and more organized place. \*tears of pride*
#
# ![yoda.webp](data:image/webp;base64,...)
